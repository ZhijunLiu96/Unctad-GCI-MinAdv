# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd 'drive/My Drive/UNGC'
# Out:
# /content/drive/My Drive/UNGC

# %% [markdown]
# # load data

# %%
score_data = pd.read_csv('two_year_result.csv')

# %%
score_data = score_data.append(pd.Series(0, index=score_data.columns), ignore_index=True)
score_data = score_data.append(pd.Series(0, index=score_data.columns), ignore_index=True)

# %%
score_data['Unnamed: 0'][32] = 'complete 1'
score_data['Unnamed: 0'][33] = 'complete 2'
score_data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Unnamed: 0  ...  2018_Arcon-Sunmark A/S
# 0       A.1.1.  ...                     2.0
# 1       A.1.2.  ...                     2.0
# 2       A.1.3.  ...                     2.0
# 3       A.2.1.  ...                     0.0
# 4       A.3.1.  ...                     0.0
# 5       A.3.2.  ...                     0.0
# ...

# %% [markdown]
# # rules:

# %% [markdown]
# 1. Institutional and governance (25)
# - [1.1]Sustainability strategy and/or principles related to sustainability
# - [1.2]Management approach to address materiality topics
# - [1.3]Governance structure, including for economic, environmental and social issues
# - [1.4]Key impacts, risks, opportunities
# - [1.5]Anti-fraud, anti-corruption and anti-competitive behaviour practices
# 2. Economic (25)
# - [2.1]Direct measure of economic performance (revenue, net profit, value added, payouts to shareholders)
# - [2.2]Indirect measure of economic performance (community investment, investment in infrastructure or other significant local economic impact)
# 3. Environmental (25)
# - [3.1]Energy consumption and energy efficiency
# - [3.2]Water consumption, wastewater generation, integrated water resource management practices, or water recycling/re-use and efficiency
# - [3.3]Waste generation, including hazardous wastes
# - [3.4]Waste minimisation and recycling practices
# - [3.5]Use and/or production of hazardous chemicals and substances
# 4. Social (25)
# - [4.1]Occupational health and safety
# - [4.2]Total number of employees, by contract type and gender
# - [4.3]Employee training
# - [4.4]Unfair and illegal labour practices and other human rights considerations
# - [4.5]Diversity, equal opportunity and discrimination in governance bodies and among employees
# - [4.6]Worker rights and collective agreements
#
#
#
# ---
# - A.2.1. tax
# - A.3.1. environment expenditure,investment,cost,pay,paid
# - A.3.2. community, charit, donation,fund,foundation investment,expenditure,investment,cost,pay,paid
# - A.3.3. research development
# - A.3.3. r&d
# - A.4.1. local procurement,purchasing,purchase
# - B.1.1. water reuse,recycle
# - B.1.2. water use,usage,consumption,consume,efficiency
# - B.1.3. water withdrawal surface,ground,rainwater,waste,rain
# - B.2.1. waste generate,generation,create,production,creation,produce change,reduc,decreas,down,low
# - B.2.2. waste reuse,recycle,remanufacture
# - B.2.3. waste hazard generate,generation,create,production,creation,produce treat,handle,recycle,ship,export,transport,compost,recover,incinerat,inject,landfill,storage
# - B.3.1. greenhouse,co2 direct,scope\s*1\s
# - B.3.2. greenhouse,co2 indirect,scope\s*2\s
# - B.4.1. ozone deplet substance,chemical
# - B.4.1. \sods\s
# - B.5.1. energy renewable
# - B.5.2. energy use,usage,consumption,consume,efficiency
# - C.1.1. women,woman,lady,ladies,female manage,lead,executive
# - C.2.1. train hour,time employ
# - C.2.2. train expenditure,investment,cost,pay,paid employ
# - C.2.3. employee,employment,workforce expenditure,investment,cost,pay,paid,wage,salary,salaries,income
# - C.3.1. employee,employment,workforce health,safe,insurance expenditure,investment,cost,pay,paid employ
# - C.3.2. injury,injuries,incident frequency,rate
# - C.4.1. collective agreement,bargain
# - D.1.1. board meeting,attendance,participate,involve,join,envolve
# - D.1.2. board women,woman,lady,ladies,female
# - D.1.3. board age
# - D.1.4. audit meeting,attendance,participate,involve,join,envolve
# - D.1.5. board,executive expenditure,cost,pay,paid,wage,salary,salaries,income
# - D.2.1. corrupt fine,punishment,penalty
# - D.2.2. corrupt train hour,time employ

# %% [markdown]
# **To be announced -> replace the example with dictionary**
#
# dictionary = {'A.1.1.': '',
#        'A.1.2.': '',
#        'A.1.3.': '',
#        'A.2.1.': '',
#        'A.3.1.': '',
#        'A.3.2.': '',
#        'A.3.3.': '',
#        'A.4.1.': '',
#        'B.1.1.': '',
#        'B.1.2.': '',
#        'B.1.3.': '',
#        'B.2.1.': '',
#        'B.2.2.': '',
#        'B.2.3.': '',
#        'B.3.1.': '',
#        'B.3.2.': '',
#        'B.5.1.': '',
#        'B.5.2.': '',
#        'C.1.1.': '',
#        'C.2.1.': '',
#        'C.2.2.': '',
#        'C.2.3.': '',
#        'C.3.1.': '',
#        'C.3.2.': '',
#        'C.4.1.': '',
#        'D.1.1.': '',
#        'D.1.2.': '',
#        'D.1.3.': '',
#        'D.1.4.': '',
#        'D.1.5.': '',
#        'D.2.1.': '',
#        'D.2.2.': ''}

# %%
weight = {
    '1.1':5,
    '1.2':5,
    '1.3':5,
    '1.4':5,
    '1.5':5,
    '2.1':12.5,
    '2.2':12.5,
    '3.1':5,
    '3.2':5,
    '3.3':5,
    '3.4':5,
    '3.5':5,
    '4.1':25/6,
    '4.2':25/6,
    '4.3':25/6,
    '4.4':25/6,
    '4.5':25/6,
    '4.6':25/6
}

# %%
example = {'A.1.1.': '1.1',
       'A.1.2.': '1.2', 
       'A.1.3.': '1.3', 
       'A.2.1.': '1.2', 
       'A.3.1.': '1.4', 
       'A.3.2.': '1.5', 
       'A.3.3.': '1.3', 
       'A.4.1.': '1.1', 
       'B.1.1.': '2.1', 
       'B.1.2.': '2.1', 
       'B.1.3.': '2.1', 
       'B.2.1.': '2.1', 
       'B.2.2.': '2.2', 
       'B.2.3.': '2.2', 
       'B.3.1.': '2.2', 
       'B.3.2.': '2.2', 
       'B.5.1.': '2.2', 
       'B.5.2.': '2.2', 
       'C.1.1.': '3.1', 
       'C.2.1.': '3.2', 
       'C.2.2.': '3.3', 
       'C.2.3.': '3.2', 
       'C.3.1.': '3.2', 
       'C.3.2.': '3.4', 
       'C.4.1.': '3.5', 
       'D.1.1.': '4.1', 
       'D.1.2.': '4.2', 
       'D.1.3.': '4.3', 
       'D.1.4.': '4.4',
       'D.1.5.': '4.3', 
       'D.2.1.': '4.5', 
       'D.2.2.': '4.6'}

# %%
# score_data = score_data.set_index('Unnamed: 0'); score_data

# %% [markdown]
# # calculate score

# %%
companies = score_data.columns.to_list()
companies = companies[1:]

# %%
ind = score_data['Unnamed: 0'].to_list(); ind

# %%
# def score(List, num):

for co in companies:
    cache = {'1.1':0, '1.2':0, '1.3':0, '1.4':0, '1.5':0, '2.1':0, '2.2':0, '3.1':0, '3.2':0, '3.3':0, '3.4':0, '3.5':0, '4.1':0, '4.2':0, '4.3':0, '4.4':0, '4.5':0, '4.6':0}
    indicator = score_data[co].to_list()[:-2]
    for i in range(32):
        if indicator[i] == 1 or indicator[i] == 2:
            cache[example[ind[i]]] = weight[example[ind[i]]]
    score_data[co][32] = sum(cache.values())

for co in companies:
    cache = {'1.1':0, '1.2':0, '1.3':0, '1.4':0, '1.5':0, '2.1':0, '2.2':0, '3.1':0, '3.2':0, '3.3':0, '3.4':0, '3.5':0, '4.1':0, '4.2':0, '4.3':0, '4.4':0, '4.5':0, '4.6':0}
    indicator = score_data[co].to_list()[:-2]
    for i in range(32):
        if indicator[i] == 2:
            cache[example[ind[i]]] = weight[example[ind[i]]]
    score_data[co][33] = sum(cache.values())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
score_data
# Out:
#     Unnamed: 0  ...  2018_Arcon-Sunmark A/S
# 0       A.1.1.  ...                     2.0
# 1       A.1.2.  ...                     2.0
# 2       A.1.3.  ...                     2.0
# 3       A.2.1.  ...                     0.0
# 4       A.3.1.  ...                     0.0
# 5       A.3.2.  ...                     0.0
# 6       A.3.3.  ...                     0.0
# 7       A.4.1.  ...                     0.0
# 8       B.1.1.  ...                     0.0
# 9       B.1.2.  ...                     1.0
# 10      B.1.3.  ...                     0.0
# 11      B.2.1.  ...                     0.0
# 12      B.2.2.  ...                     0.0
# 13      B.2.3.  ...                     0.0
# 14      B.3.1.  ...                     0.0
# 15      B.3.2.  ...                     0.0
# 16      B.5.1.  ...                     0.0
# 17      B.5.2.  ...                     1.0
# 18      C.1.1.  ...                     0.0
# 19      C.2.1.  ...                     0.0
# ...

# %%
score_data.to_csv('score.csv',index=False)

# %%
score_data = pd.read_csv('score.csv')
